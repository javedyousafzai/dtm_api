# %%
from dtmapi import DTMApi
# Initialize with your subscription key (defaults to v3)
import os
from dotenv import load_dotenv
api = DTMApi(subscription_key="DTMAPI_SUBSCRIPTION_KEY")
